# %% [markdown]
# # Importing Data

# %%
import numpy as np               # used for multidimensional arrays
import pandas as pd              # used for import the dataset
import matplotlib.pyplot as plt  # used for visualising graphs
import seaborn as sns            # used for visualising graphs
#this will make your plot outputs appear and be stored within the notebook
# %matplotlib inline

# %%
# Reading a CSV file named 'Census.csv' into a pandas DataFrame.
df = pd.read_csv('Census.csv')

# %%
# Display first 5 rows
df.head()
# Out:
#    Person ID     Region Residence Type  Family Composition  Population Base  \
# 0    7394816  E12000001              H                   2                1
# 1    7394832  E12000001              H                   3                1
# 2    7394719  E12000001              H                   2                1
# 3    7394840  E12000001              H                   1                1
# 4    7394711  E12000001              H                   2                1
#
#    Sex  Age  Marital Status  Student  Country of Birth  Health  Ethnic Group  \
# 0    2    6               2        2                 1       2             1
# 1    2    1               1        2                 1       2             1
# 2    1    7               2        2                 1       1             1
# 3    2    6               4        2                 1       3             1
# 4    1    1               1        1                 1       1             1
#
# ...

# %%
# Display last 5 rows
df.tail()
# Out:
#         Person ID     Region Residence Type  Family Composition  \
# 569735    7680019  E12000008              C                  -9
# 569736    7675184  E12000008              C                  -9
# 569737    7675176  E12000008              C                  -9
# 569738    7944614  W92000004              H                   2
# 569739    7945074  W92000004              H                   1
#
#         Population Base  Sex  Age  Marital Status  Student  Country of Birth  \
# 569735                1    1    2               1        2                 2
# 569736                1    1    3               1        2                 2
# 569737                1    2    5               2        2                 1
# 569738                1    1    6               2        2                 1
# 569739                1    1    5               4        2                 1
#
#         Health  Ethnic Group  Religion  Economic Activity  Occupation  \
# ...

# %% [markdown]
# # Basic Statistics

# %%
# Get shape of the DataFrame
df.shape
# Out:
# (569740, 19)

# %%
# Get data types of each column
df.dtypes
# Out:
# Person ID                      int64
# Region                        object
# Residence Type                object
# Family Composition             int64
# Population Base                int64
# Sex                            int64
# Age                            int64
# Marital Status                 int64
# Student                        int64
# Country of Birth               int64
# Health                         int64
# Ethnic Group                   int64
# Religion                       int64
# Economic Activity              int64
# Occupation                     int64
# Industry                       int64
# Hours worked per week          int64
# No of hours                  float64
# Approximated Social Grade      int64
# dtype: object

# %%
df.describe()
# Out:
#           Person ID  Family Composition  Population Base            Sex  \
# count  5.697400e+05        569740.00000    569740.000000  569740.000000
# mean   7.679353e+06             2.01187         1.018731       1.507551
# std    1.644699e+05             2.35879         0.159058       0.499943
# min    7.394483e+06            -9.00000         1.000000       1.000000
# 25%    7.536918e+06             2.00000         1.000000       1.000000
# 50%    7.679352e+06             2.00000         1.000000       2.000000
# 75%    7.821787e+06             3.00000         1.000000       2.000000
# max    7.964223e+06             6.00000         3.000000       2.000000
#
#                  Age  Marital Status        Student  Country of Birth  \
# count  569740.000000   569740.000000  569740.000000     569740.000000
# mean        3.978676        1.856201       1.777904          1.016237
# std         2.219494        1.125021       0.415656          1.153095
# ...

# %%
columns_to_convert = [
    'Family Composition', 'Population Base', 'Sex', 'Age', 'Marital Status', 
    'Student', 'Country of Birth', 'Health', 'Ethnic Group', 'Religion', 
    'Economic Activity', 'Occupation', 'Industry', 'Hours worked per week', 
    'Approximated Social Grade']
# Convert all listed columns to string type .
df[columns_to_convert] = df[columns_to_convert].astype(str)

# %%
# Check the data types of each column after conversion
df.dtypes
# Out:
# Person ID                      int64
# Region                        object
# Residence Type                object
# Family Composition            object
# Population Base               object
# Sex                           object
# Age                           object
# Marital Status                object
# Student                       object
# Country of Birth              object
# Health                        object
# Ethnic Group                  object
# Religion                      object
# Economic Activity             object
# Occupation                    object
# Industry                      object
# Hours worked per week         object
# No of hours                  float64
# Approximated Social Grade     object
# dtype: object

# %%
# Display the count of each unique value in the 'Population Base' column
df['Population Base'].value_counts()
# Out:
# Population Base
# 1    561039
# 2      6730
# 3      1971
# Name: count, dtype: int64

# %% [markdown]
# # Data Labeling

# %%
df['Region'] = df['Region'].replace({
    'E12000008': 'South East',
    'E12000007': 'London',
    'E12000006': 'East of England',
    'E12000005': 'West Midlands',
    'E12000004': 'East Midlands',
    'E12000003': 'Yorkshire and the Humber',
    'E12000002': 'North West',
    'E12000001': 'North East',
    'E12000009': 'South West',
    'W92000004': 'Wales'
})

df['Residence Type'] = df['Residence Type'].replace({
    'C': 'communal establishment',
    'H':'Not a communal establishment'
})

df['Family Composition'] = df['Family Composition'].replace({
    '1': 'Not in a family',
    '2': 'Married',
    '3':'Cohabiting couple family',
    '4': 'Lone male parent family',
    '5':'Lone female parent family',
    '6':'Other related family',
    '-9':'short-term resident'
})

df['Population Base'] = df['Population Base'].replace({
    '1':'Usual resident',
    '2':'Student living away from home',
    '3':'Short term resident'
})

df['Sex'] = df['Sex'].replace({
    '1': 'Male',
    '2':'Female'
})

df['Age'] = df['Age'].replace({
    '1': '0 to 15',
    '2':'16 to 24',
    '3':'25 to 34',
    '4':'35 to 44',
    '5':'45 to 54',
    '6':'55 to 64',
    '7':'65 to 74',
    '8':'75 and over' 
})
df['Marital Status'] = df['Marital Status'].replace({
    '1': 'Single',
    '2': 'Married',
    '3': 'Separated but still legally married',
    '4': 'Divorced',
    '5':'Widowed'
})

df['Student'] = df['Student'].replace({
    '1': 'Yes',
    '2':'No'
})

df['Country of Birth'] = df['Country of Birth'].replace({
    '1': 'UK',
    '2':'Non UK',
    '-9':'Students or schoolchildren living away during term-time'
})

df['Health'] = df['Health'].replace({
    '1': 'Very good health',
    '2':'Good health',
    '3':'Fair health',
    '4':'Bad health',
    '5':'Very bad health',
   '-9':'Students or schoolchildren living away during term-time'
})

df['Ethnic Group'] = df['Ethnic Group'].replace({
    '1':'White',
'2':'Mixed',
'3': 'Asian and Asian British',
'4':'Black or Black British',
'5':'Chinese',
'-9': 'students or schoolchildren living away during term-time'
})

df['Religion'] = df['Religion'].replace({
    '1': 'No religion',
'2':'Christian',
'3': 'Buddhist',
'4':'Hindu',
'5': 'Jewish',
'6':'Muslim',
'7': 'Sikh',
'8':'Other religion',
'9':'Not stated',
'-9':'students or schoolchildren living away during term-time'
})

df['Economic Activity'] = df['Economic Activity'].replace({
    '1': 'Employee',
    '2': 'Self-employed',
    '3': 'Unemployed',
    '4': 'Full-time student',
    '5': 'Retired',
    '6': 'Student',
    '7': 'Looking after home or family',
    '8': 'Long-term sick or disabled',
    '9': 'Other',
    '-9': 'students or schoolchildren living away during term-time'
})

df['Occupation'] = df['Occupation'].replace({
    '1': 'Managers',
    '2': 'Professional Occupations',
    '3': 'Associate Technical Occupations',
    '4': 'Administrative and Secretarial Occupations',
    '5': 'Skilled Trades Occupations',
    '6': 'Caring Other Service Occupations',
    '7': 'Sales and Customer Service Occupations',
    '8': 'Process, Plant and Machine Operatives',
    '9': 'Elementary Occupations',
    '-9': 'People aged under 16'
})

df['Industry'] = df['Industry'].replace({
    '1': 'Agriculture and fishing',
    '2': 'Mining and Manufacturing',
    '3': 'Construction',
    '4': 'Wholesale and retail trade',
    '5': 'Accommodation and food service',
    '6': 'Transport and storage',
    '7': 'Financial and insurance',
    '8': 'Real estate activities',
    '9': 'Public administration and defence',
    '10': 'Education',
    '11': 'Human health and social work',
    '12': 'Other community activities',
    '-9': 'People aged under 16'
})

df['Hours worked per week'] = df['Hours worked per week'].replace({
   '1' :'15 or less',
    '2': '16 to 30',
    '3':'31 to 48',
    '4': '49 or more',
    '-9':'people not working'
})

df['Approximated Social Grade'] = df['Approximated Social Grade'].replace({
    '1': 'AB',
    '2':'C1',
   '3': 'C2',
   '4':'DE',
   '-9': 'People aged under 16'
})

# %%
# Statistical summary of the numerical columns in the DataFrame
df.describe()
# Out:
#           Person ID    No of hours
# count  5.697400e+05  267419.000000
# mean   7.679353e+06      35.234789
# std    1.644699e+05      13.520881
# min    7.394483e+06       1.000000
# 25%    7.536918e+06      27.000000
# 50%    7.679352e+06      37.000000
# 75%    7.821787e+06      45.000000
# max    7.964223e+06      60.000000

# %%
# Summary of all columns in the DataFrame (both numeric and categorical)
df.describe(include = 'all')
# Out:
#            Person ID      Region                Residence Type  \
# count   5.697400e+05      569740                        569740
# unique           NaN          10                             2
# top              NaN  South East  Not a communal establishment
# freq             NaN       88084                        559086
# mean    7.679353e+06         NaN                           NaN
# std     1.644699e+05         NaN                           NaN
# min     7.394483e+06         NaN                           NaN
# 25%     7.536918e+06         NaN                           NaN
# 50%     7.679352e+06         NaN                           NaN
# 75%     7.821787e+06         NaN                           NaN
# max     7.964223e+06         NaN                           NaN
#
#        Family Composition Population Base     Sex      Age Marital Status  \
# count              569740          569740  569740   569740         569740
# ...

# %%
# List of column names in the DataFrame
df.columns
# Out:
# Index(['Person ID', 'Region', 'Residence Type', 'Family Composition',
#        'Population Base', 'Sex', 'Age', 'Marital Status', 'Student',
#        'Country of Birth', 'Health', 'Ethnic Group', 'Religion',
#        'Economic Activity', 'Occupation', 'Industry', 'Hours worked per week',
#        'No of hours', 'Approximated Social Grade'],
#       dtype='object')

# %%
df.median(numeric_only = True)
# Out:
# Person ID      7679352.5
# No of hours         37.0
# dtype: float64

# %%
# To identify the most common values in a dataset.
#df.mode()

# %% [markdown]
# # Data visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Box plot for Age vs Approximated Social Grade
plt.figure(figsize=(10, 6))
sns.boxplot(x='Approximated Social Grade', y='Age', data=df)
plt.title('Age Distribution by Approximated Social Grade')
plt.show()

# %%
# Group by Region and Approximated Social Grade, then sum the counts
region_social_grade = df.groupby(['Region', 'Approximated Social Grade']).size().unstack(fill_value=0)
# Plotting the result as a stacked bar plot
region_social_grade.plot(kind='bar', stacked=True,figsize=(16,6))
plt.title('Social Grade Distribution by Region')
plt.xlabel('Region')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Create the crosstab table between 'Population Base' and 'Approximated Social Grade'
ct = pd.crosstab(df['Population Base'], df['Approximated Social Grade'])
plt.figure(figsize=(10, 6))
sns.heatmap(ct, annot=True, fmt="d", cmap="YlGnBu", linewidths=0.5)
plt.title('Heatmap of Population Base vs. Approximated Social Grade')
plt.xlabel('Approximated Social Grade')
plt.ylabel('Population Base');

# %%
# Create the crosstab table between 'Occupation' and 'Approximated Social Grade'
occupation_social_grade = pd.crosstab(df['Occupation'], df['Approximated Social Grade'])
# Show the plot
plt.show()
occupation_social_grade.T.plot(kind='line', figsize=(10, 6), marker='o')
plt.xlabel('Approximated Social Grade')
plt.ylabel('Count')
plt.title('Line Plot of Approximated Social Grade Across Occupations')
plt.legend(title='Occupation', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
# Clustered Bar Plot
ethnic_age = pd.crosstab(df['Age'], df['Ethnic Group'])
ethnic_age.plot(kind='bar', figsize=(12, 6))
plt.title('Ethnic Group Distribution by Age')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Ethnic Group');

# %% [markdown]
# # Data Preprocessing

# %%
#import package for chi-square test
from scipy.stats import chi2_contingency
# Reading a CSV file named 'Census.csv' into a pandas DataFrame.
df = pd.read_csv('Census.csv')
df.head()
# Out:
#    Person ID     Region Residence Type  Family Composition  Population Base  \
# 0    7394816  E12000001              H                   2                1
# 1    7394832  E12000001              H                   3                1
# 2    7394719  E12000001              H                   2                1
# 3    7394840  E12000001              H                   1                1
# 4    7394711  E12000001              H                   2                1
#
#    Sex  Age  Marital Status  Student  Country of Birth  Health  Ethnic Group  \
# 0    2    6               2        2                 1       2             1
# 1    2    1               1        2                 1       2             1
# 2    1    7               2        2                 1       1             1
# 3    2    6               4        2                 1       3             1
# 4    1    1               1        1                 1       1             1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569740 entries, 0 to 569739
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Person ID                  569740 non-null  int64
#  1   Region                     569740 non-null  object
#  2   Residence Type             569740 non-null  object
#  3   Family Composition         569740 non-null  int64
#  4   Population Base            569740 non-null  int64
#  5   Sex                        569740 non-null  int64
#  6   Age                        569740 non-null  int64
#  7   Marital Status             569740 non-null  int64
#  8   Student                    569740 non-null  int64
#  9   Country of Birth           569740 non-null  int64
#  10  Health                     569740 non-null  int64
#  11  Ethnic Group               569740 non-null  int64
#  12  Religion                   569740 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Person ID                         0
# Region                            0
# Residence Type                    0
# Family Composition                0
# Population Base                   0
# Sex                               0
# Age                               0
# Marital Status                    0
# Student                           0
# Country of Birth                  0
# Health                            0
# Ethnic Group                      0
# Religion                          0
# Economic Activity                 0
# Occupation                        0
# Industry                          0
# Hours worked per week             0
# No of hours                  302321
# Approximated Social Grade         0
# dtype: int64

# %%
df.shape
# Out:
# (569740, 19)

# %%
print('Total missing data is :',round((df['No of hours'].isnull().sum() * 100)/df.shape[0],2),'%')
# Out:
# Total missing data is : 53.06 %

# %%
df['No of hours'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['No of hours'].median()
# Out:
# 37.0

# %%
df['No of hours'].fillna(37.0,inplace = True)

# %%
df['No of hours'].isnull().sum()
# Out:
# 0

# %%
df.replace(-9,0, inplace=True)

# %%
df.drop_duplicates()
# Out:
#         Person ID     Region Residence Type  Family Composition  \
# 0         7394816  E12000001              H                   2
# 1         7394832  E12000001              H                   3
# 2         7394719  E12000001              H                   2
# 3         7394840  E12000001              H                   1
# 4         7394711  E12000001              H                   2
# ...           ...        ...            ...                 ...
# 569735    7680019  E12000008              C                   0
# 569736    7675184  E12000008              C                   0
# 569737    7675176  E12000008              C                   0
# 569738    7944614  W92000004              H                   2
# 569739    7945074  W92000004              H                   1
#
#         Population Base  Sex  Age  Marital Status  Student  Country of Birth  \
# 0                     1    2    6               2        2                 1
# ...

# %%
df.drop('Person ID',axis = 1,inplace = True)

# %%
df.shape
# Out:
# (569740, 18)

# %%
contigency=pd.crosstab(df['Residence Type'], df['Approximated Social Grade'])
contigency
# Out:
# Approximated Social Grade       0      1       2      3       4
# Residence Type
# C                           10654      0       0      0       0
# H                          113449  82320  159642  79936  123739

# %%
# Chi-square test of independence.
c, p, dof, expected = chi2_contingency(contigency)
# Print the p-value
print(p)
# Out:
# 0.0

# %%
contigency=pd.crosstab(df['Region'], df['Approximated Social Grade'])
contigency
# Out:
# Approximated Social Grade      0      1      2      3      4
# Region
# E12000001                   5453   2966   7110   4003   6817
# E12000002                  15330   8960  19786   9992  17368
# E12000003                  11467   6629  14284   7927  13164
# E12000004                   9921   5785  12197   6885  10994
# E12000005                  12681   7041  14835   8513  13805
# E12000006                  12847   8749  16877   8768  12170
# E12000007                  18992  15518  25124   8886  15062
# E12000008                  19782  15119  25852  11811  15520
# E12000009                  11115   7875  15327   8321  11136
# W92000004                   6515   3678   8250   4830   7703

# %%
# Chi-square test of independence.
c, p, dof, expected = chi2_contingency(contigency)
# Print the p-value
print(p)
# Out:
# 0.0

# %%
from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()
df['Residence Type'] = LE.fit_transform(df['Residence Type'])
df['Region'] = LE.fit_transform(df['Region'])

# %%
df.columns
# Out:
# Index(['Region', 'Residence Type', 'Family Composition', 'Population Base',
#        'Sex', 'Age', 'Marital Status', 'Student', 'Country of Birth', 'Health',
#        'Ethnic Group', 'Religion', 'Economic Activity', 'Occupation',
#        'Industry', 'Hours worked per week', 'No of hours',
#        'Approximated Social Grade'],
#       dtype='object')

# %%
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()

#for just one numerical variable
df[['No of hours']]= min_max_scaler.fit_transform(df[['No of hours']])

# %%
df.head(10)
# Out:
#    Region  Residence Type  Family Composition  Population Base  Sex  Age  \
# 0       0               1                   2                1    2    6
# 1       0               1                   3                1    2    1
# 2       0               1                   2                1    1    7
# 3       0               1                   1                1    2    6
# 4       0               1                   2                1    1    1
# 5       0               1                   1                1    2    2
# 6       0               1                   1                1    2    2
# 7       0               1                   3                1    1    2
# 8       0               1                   2                1    1    1
# 9       0               1                   2                1    1    7
#
#    Marital Status  Student  Country of Birth  Health  Ethnic Group  Religion  \
# 0               2        2                 1       2             1         2
# ...

# %%
df_sample=df.sample(frac=0.1, replace=False, random_state=42)

# %%
df.shape
# Out:
# (569740, 18)

# %%
df_sample.shape
# Out:
# (56974, 18)

# %%
df_sample1=df.groupby('Approximated Social Grade', group_keys=False).apply(lambda x: x.sample(frac=0.1))

# %%
df_sample1.shape
# Out:
# (56974, 18)

# %%
df['Approximated Social Grade'].value_counts()
# Out:
# Approximated Social Grade
# 2    159642
# 0    124103
# 4    123739
# 1     82320
# 3     79936
# Name: count, dtype: int64

# %%
df_sample['Approximated Social Grade'].value_counts()
# Out:
# Approximated Social Grade
# 2    15870
# 0    12638
# 4    12321
# 1     8184
# 3     7961
# Name: count, dtype: int64

# %%
df_sample1['Approximated Social Grade'].value_counts()
# Out:
# Approximated Social Grade
# 2    15964
# 0    12410
# 4    12374
# 1     8232
# 3     7994
# Name: count, dtype: int64

# %%
X = df_sample.iloc[:,:-1].values    # predictor attributes
y = df_sample.iloc[:,-1].values     # target attribute

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn import preprocessing


knn= KNeighborsClassifier(n_neighbors=5)

#fit the clasifier to the data
knn.fit(X_train,y_train)
#predicted values using the knn model
y_pred=knn.predict(X_test)

#performance metrics
from sklearn import metrics
#from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

print(confusion_matrix(y_test, y_pred), '\n')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)), '\n')

print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))
y_pred_proba = knn.predict_proba(X_test)  # Get predicted probabilities
print("AUC:", roc_auc_score(y_test, y_pred_proba, multi_class='ovr'))
# Out:
# [[3053   13   77    9   43]
#  [   0 1417  510   44   82]
#  [   3  582 2848  224  248]
#  [   2   67  244 1138  503]
#  [   5   82  278  507 2265]]
#
# Mean Absolute Error: 0.33235046335299073
# Mean Squared Error: 0.5471777590564448
# Root Mean Squared Error: 0.7397146470473901
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98      3195
#            1       0.66      0.69      0.67      2053
#            2       0.72      0.73      0.72      3905
#            3       0.59      0.58      0.59      1954
#            4       0.72      0.72      0.72      3137
#
#     accuracy                           0.75     14244
#    macro avg       0.74      0.74      0.74     14244
# weighted avg       0.76      0.75      0.75     14244
#
# Accuracy: 0.7526677899466442
# AUC: 0.9231424065027817

# %%
# try k=1 through k=10 and record accuracy
k_range = range(1, 10)

# create a Python dictionary using [] or dict()
scores = []

# loop through the k values; append the scores in the dictionary
for k in k_range:
    kNN = KNeighborsClassifier(n_neighbors=k)
    kNN.fit(X_train, y_train)
    y_pred = kNN.predict(X_test)
    scores.append(metrics.accuracy_score(y_test, y_pred))
print(scores)
# Out:
# [0.7306234203875316, 0.7117382757652345, 0.7457174950856501, 0.746489750070205, 0.7526677899466442, 0.7567396798652064, 0.7596180848076383, 0.7620752597584948, 0.7629879247402415]

# %%
# plot the relationship between k values and accuracy
# plt.plot(x_axis, y_axis)
plt.plot(k_range, scores)
plt.xlabel('Value of k for kNN')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
#kNN cross-validation
from sklearn.model_selection import cross_val_score
kNN = KNeighborsClassifier(n_neighbors=8)

#accuracy scores for each fold
scores = cross_val_score(kNN, X, y, cv=10)
print(scores)

#print the average accuracy across all folds
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# [0.76921727 0.76553177 0.77571078 0.76974377 0.77040548 0.76426189
#  0.77075654 0.76584167 0.7682991  0.76952782]
# Accuracy: 0.77 (+/- 0.01)

# %%
#performance metrics

from sklearn.model_selection import cross_val_predict

#predicted values
y_pred = cross_val_predict(kNN, X, y, cv=10)

print(confusion_matrix(y, y_pred), '\n')
print('Mean Absolute Error:', metrics.mean_absolute_error(y, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y, y_pred)), '\n')

print(classification_report(y, y_pred))
print("Accuracy:", accuracy_score(y, y_pred))
# Out:
# [[12071    60   252    61   194]
#  [    0  6181  1542   156   305]
#  [    6  2712 11298   799  1055]
#  [    1   229   920  4914  1897]
#  [   20   259   975  1722  9345]]
#
# Mean Absolute Error: 0.31122968371537896
# Mean Squared Error: 0.5160599571734475
# Root Mean Squared Error: 0.7183731322742016
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     12638
#            1       0.65      0.76      0.70      8184
#            2       0.75      0.71      0.73     15870
#            3       0.64      0.62      0.63      7961
#            4       0.73      0.76      0.74     12321
#
#     accuracy                           0.77     56974
#    macro avg       0.76      0.76      0.76     56974
# weighted avg       0.77      0.77      0.77     56974
#
# Accuracy: 0.7689296872257521

# %% [markdown]
# # Naive Bases

# %%
from sklearn.naive_bayes import GaussianNB

# initialize the Naive Bayes classifier
NB = GaussianNB()

#fit the classifier to the data
NB.fit(X_train,y_train)

#use the resulting model to predict value on the test sey
y_pred = NB.predict(X_test)

#performance metrics
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score

print(confusion_matrix(y_test, y_pred), '\n')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)), '\n')

print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))
y_pred_proba = NB.predict_proba(X_test)  # Get predicted probabilities
print("AUC:", roc_auc_score(y_test, y_pred_proba, multi_class='ovr'))
# Out:
# [[ 513  476 2049    0  157]
#  [   0 1753    3   31  266]
#  [   0 1972  782  382  769]
#  [   0   78    1 1250  625]
#  [   0  108    1 1040 1988]]
#
# Mean Absolute Error: 0.8498315080033698
# Mean Squared Error: 1.5507582139848357
# Root Mean Squared Error: 1.245294428633179
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.16      0.28      3195
#            1       0.40      0.85      0.54      2053
#            2       0.28      0.20      0.23      3905
#            3       0.46      0.64      0.54      1954
#            4       0.52      0.63      0.57      3137
#
#     accuracy                           0.44     14244
#    macro avg       0.53      0.50      0.43     14244
# weighted avg       0.54      0.44      0.40     14244
#
# Accuracy: 0.4413086211738276
# AUC: 0.8446226792946685

# %%
#cross-validation
from sklearn.model_selection import cross_val_score
NB1 = GaussianNB()

#accuracy scores for each fold
scores = cross_val_score(NB1, X, y, cv=10)
print(scores)

#print the average accuracy across all folds
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# [0.44559495 0.44928045 0.45121095 0.44313794 0.45339652 0.44461998
#  0.44619975 0.45023697 0.43742321 0.44830613]
# Accuracy: 0.45 (+/- 0.01)

# %%
#performance metrics

from sklearn.model_selection import cross_val_predict

#predicted values
y_pred = cross_val_predict(NB1, X, y, cv=10)

print(confusion_matrix(y, y_pred), '\n')
print('Mean Absolute Error:', metrics.mean_absolute_error(y, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y, y_pred)), '\n')

print(classification_report(y, y_pred))
print("Accuracy:", accuracy_score(y, y_pred))
# Out:
# [[2138 1810 8107    0  583]
#  [   0 6884   11  119 1170]
#  [   0 7685 3199 1599 3387]
#  [   0  335    4 4939 2683]
#  [   0  345    7 3665 8304]]
#
# Mean Absolute Error: 0.8467722118861235
# Mean Squared Error: 1.548776634956296
# Root Mean Squared Error: 1.2444985475910753
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.17      0.29     12638
#            1       0.40      0.84      0.55      8184
#            2       0.28      0.20      0.24     15870
#            3       0.48      0.62      0.54      7961
#            4       0.51      0.67      0.58     12321
#
#     accuracy                           0.45     56974
#    macro avg       0.54      0.50      0.44     56974
# weighted avg       0.54      0.45      0.41     56974
#
# Accuracy: 0.4469407097974515

# %% [markdown]
# # MLPClassifier

# %%
#import the classifier
from sklearn.neural_network import MLPClassifier

# initialize the classifier
MLP = MLPClassifier(activation='relu',solver='adam',random_state=42,max_iter=1000)

#fit the classifier to the data
MLP.fit(X_train, y_train)

#use the resulting model to predict value on the test sey
y_pred = MLP.predict(X_test)

#performance metrics
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score

print(confusion_matrix(y_test, y_pred), '\n')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)), '\n')

print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))
y_pred_proba = MLP.predict_proba(X_test)  # Get predicted probabilities
print("AUC:", roc_auc_score(y_test, y_pred_proba, multi_class='ovr'))
# Out:
# [[3195    0    0    0    0]
#  [   0 1568  381   12   92]
#  [   0  566 2974   95  270]
#  [   0   44  169 1082  659]
#  [   0   56  201  238 2642]]
#
# Mean Absolute Error: 0.2531592249368155
# Mean Squared Error: 0.38949733221005334
# Root Mean Squared Error: 0.6240972137496316
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3195
#            1       0.70      0.76      0.73      2053
#            2       0.80      0.76      0.78      3905
#            3       0.76      0.55      0.64      1954
#            4       0.72      0.84      0.78      3137
#
#     accuracy                           0.80     14244
#    macro avg       0.80      0.78      0.79     14244
# weighted avg       0.81      0.80      0.80     14244
#
# Accuracy: 0.8046194889076103
# AUC: 0.9638518390976898

# %%
#cross-validation
from sklearn.model_selection import cross_val_score
MLP1 = MLPClassifier(activation='relu',solver='adam',random_state=42,max_iter=1000)

#accuracy scores for each fold
scores = cross_val_score(MLP1, X, y, cv=10)
print(scores)

#print the average accuracy across all folds
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# [0.81590032 0.81449631 0.81853282 0.81941032 0.81621906 0.80551167
#  0.8232403  0.81709672 0.81569247 0.81902756]
# Accuracy: 0.82 (+/- 0.01)

# %%
#performance metrics

from sklearn.model_selection import cross_val_predict

#predicted values
y_pred = cross_val_predict(MLP1, X, y, cv=10)

print(confusion_matrix(y, y_pred), '\n')
print('Mean Absolute Error:', metrics.mean_absolute_error(y, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y, y_pred)), '\n')

print(classification_report(y, y_pred))
print("Accuracy:", accuracy_score(y, y_pred))
# Out:
# [[12638     0     0     0     0]
#  [    0  5999  1675   172   338]
#  [    0  1778 12505   583  1004]
#  [    0   184   421  5472  1884]
#  [    0   184   599  1632  9906]]
#
# Mean Absolute Error: 0.23619545757714044
# Mean Squared Error: 0.35993611120862146
# Root Mean Squared Error: 0.5999467569781683
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     12638
#            1       0.74      0.73      0.73      8184
#            2       0.82      0.79      0.80     15870
#            3       0.70      0.69      0.69      7961
#            4       0.75      0.80      0.78     12321
#
#     accuracy                           0.82     56974
#    macro avg       0.80      0.80      0.80     56974
# weighted avg       0.82      0.82      0.82     56974
#
# Accuracy: 0.8165127953101414

# %% [markdown]
# # Bagging

# %%
#import bagging
from sklearn.ensemble import BaggingClassifier

#initialise classifier
BC = BaggingClassifier(n_estimators=10, random_state=0)
#fit the classifier to the data
BC.fit(X_train, y_train)

#predict the values for the test set
y_pred = BC.predict(X_test)

#performance metrics
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score

print(confusion_matrix(y_test, y_pred), '\n')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)), '\n')

print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))
y_pred_proba = BC.predict_proba(X_test)  # Get predicted probabilities
print("AUC:", roc_auc_score(y_test, y_pred_proba, multi_class='ovr'))
# Out:
# [[3187    1    4    2    1]
#  [   0 1506  414   46   87]
#  [   0  472 3061  152  220]
#  [   0   60  155 1266  473]
#  [   0   83  206  449 2399]]
#
# Mean Absolute Error: 0.2603201347935973
# Mean Squared Error: 0.40887391182252175
# Root Mean Squared Error: 0.639432491997804
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3195
#            1       0.71      0.73      0.72      2053
#            2       0.80      0.78      0.79      3905
#            3       0.66      0.65      0.65      1954
#            4       0.75      0.76      0.76      3137
#
#     accuracy                           0.80     14244
#    macro avg       0.78      0.79      0.78     14244
# weighted avg       0.80      0.80      0.80     14244
#
# Accuracy: 0.8016708789665824
# AUC: 0.9460330325440198

# %%
#cross-validation
from sklearn.model_selection import cross_val_score
BC1 = BaggingClassifier(n_estimators=10, random_state=0)

#accuracy scores for each fold
scores = cross_val_score(BC1, X, y, cv=10)
print(scores)

#print the average accuracy across all folds
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# [0.80659881 0.7990523  0.80589681 0.80852931 0.80551167 0.79568194
#  0.80551167 0.79936809 0.81165526 0.80884676]
# Accuracy: 0.80 (+/- 0.01)

# %%
#performance metrics

from sklearn.model_selection import cross_val_predict

#predicted values
y_pred = cross_val_predict(BC1, X, y, cv=10)

print(confusion_matrix(y, y_pred), '\n')
print('Mean Absolute Error:', metrics.mean_absolute_error(y, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y, y_pred)), '\n')

print(classification_report(y, y_pred))
print("Accuracy:", accuracy_score(y, y_pred))
# Out:
# [[12619     3     2     9     5]
#  [    0  6036  1613   206   329]
#  [    0  1931 12483   549   907]
#  [    0   245   603  5441  1672]
#  [    0   337   914  1804  9266]]
#
# Mean Absolute Error: 0.2592059535928669
# Mean Squared Error: 0.4111700073717836
# Root Mean Squared Error: 0.6412253951394811
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     12638
#            1       0.71      0.74      0.72      8184
#            2       0.80      0.79      0.79     15870
#            3       0.68      0.68      0.68      7961
#            4       0.76      0.75      0.76     12321
#
#     accuracy                           0.80     56974
#    macro avg       0.79      0.79      0.79     56974
# weighted avg       0.81      0.80      0.80     56974
#
# Accuracy: 0.8046652859198933

# %% [markdown]
# # XgBoost

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# %%
model = XGBClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
y_pred = model.predict(X_test)
print(confusion_matrix(y_test, y_pred), '\n')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)), '\n')

print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))
y_pred_proba = model.predict_proba(X_test)  # Get predicted probabilities
print("AUC:", roc_auc_score(y_test, y_pred_proba, multi_class='ovr'))
# Out:
# [[3195    0    0    0    0]
#  [   0 1500  433   28   92]
#  [   0  332 3202  114  257]
#  [   0   48   95 1286  525]
#  [   0   50  139  303 2645]]
#
# Mean Absolute Error: 0.2226902555461949
# Mean Squared Error: 0.34877843302443134
# Root Mean Squared Error: 0.590574663378333
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3195
#            1       0.78      0.73      0.75      2053
#            2       0.83      0.82      0.82      3905
#            3       0.74      0.66      0.70      1954
#            4       0.75      0.84      0.79      3137
#
#     accuracy                           0.83     14244
#    macro avg       0.82      0.81      0.81     14244
# weighted avg       0.83      0.83      0.83     14244
#
# Accuracy: 0.8303847233923055
# AUC: 0.9711478958428424

# %%
#cross-validation
from sklearn.model_selection import cross_val_score
model1 = XGBClassifier()

#accuracy scores for each fold
scores = cross_val_score(NB1, X, y, cv=10)
print(scores)

#print the average accuracy across all folds
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# [0.44559495 0.44928045 0.45121095 0.44313794 0.45339652 0.44461998
#  0.44619975 0.45023697 0.43742321 0.44830613]
# Accuracy: 0.45 (+/- 0.01)

# %%
#performance metrics

from sklearn.model_selection import cross_val_predict

#predicted values
y_pred = cross_val_predict(model1, X, y, cv=10)

print(confusion_matrix(y, y_pred), '\n')
print('Mean Absolute Error:', metrics.mean_absolute_error(y, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y, y_pred)), '\n')

print(classification_report(y, y_pred))
print("Accuracy:", accuracy_score(y, y_pred))
# Out:
# [[12638     0     0     0     0]
#  [    0  6098  1603   124   359]
#  [    0  1370 13068   402  1030]
#  [    0   178   396  5410  1977]
#  [    0   167   598  1203 10353]]
#
# Mean Absolute Error: 0.21745006494190333
# Mean Squared Error: 0.3405939551374311
# Root Mean Squared Error: 0.5836042795742944
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     12638
#            1       0.78      0.75      0.76      8184
#            2       0.83      0.82      0.83     15870
#            3       0.76      0.68      0.72      7961
#            4       0.75      0.84      0.80     12321
#
#     accuracy                           0.83     56974
#    macro avg       0.83      0.82      0.82     56974
# weighted avg       0.84      0.83      0.83     56974
#
# Accuracy: 0.8348895987643487

# %% [markdown]
# # Regression

# %%
import pandas as pd
import numpy as np
# Reading a CSV file named 'Census.csv' into a pandas DataFrame.
df = pd.read_csv('Census.csv')
df.head()
# Out:
#    Person ID     Region Residence Type  Family Composition  Population Base  \
# 0    7394816  E12000001              H                   2                1
# 1    7394832  E12000001              H                   3                1
# 2    7394719  E12000001              H                   2                1
# 3    7394840  E12000001              H                   1                1
# 4    7394711  E12000001              H                   2                1
#
#    Sex  Age  Marital Status  Student  Country of Birth  Health  Ethnic Group  \
# 0    2    6               2        2                 1       2             1
# 1    2    1               1        2                 1       2             1
# 2    1    7               2        2                 1       1             1
# 3    2    6               4        2                 1       3             1
# 4    1    1               1        1                 1       1             1
#
# ...

# %%
df.columns
# Out:
# Index(['Person ID', 'Region', 'Residence Type', 'Family Composition',
#        'Population Base', 'Sex', 'Age', 'Marital Status', 'Student',
#        'Country of Birth', 'Health', 'Ethnic Group', 'Religion',
#        'Economic Activity', 'Occupation', 'Industry', 'Hours worked per week',
#        'No of hours', 'Approximated Social Grade'],
#       dtype='object')

# %% [markdown]
# ## Preprocessing the Data

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
df['Residence Type'] = LE.fit_transform(df['Residence Type'])
df['Region'] = LE.fit_transform(df['Region'])

# %%
df.replace(-9, 0, inplace=True)

# %%
df.drop('Person ID',axis = 1,inplace = True)

# %%
df.shape
# Out:
# (569740, 18)

# %%
df.isnull().sum()
# Out:
# Region                            0
# Residence Type                    0
# Family Composition                0
# Population Base                   0
# Sex                               0
# Age                               0
# Marital Status                    0
# Student                           0
# Country of Birth                  0
# Health                            0
# Ethnic Group                      0
# Religion                          0
# Economic Activity                 0
# Occupation                        0
# Industry                          0
# Hours worked per week             0
# No of hours                  302321
# Approximated Social Grade         0
# dtype: int64

# %%
df.dropna(axis = 0,inplace = True)

# %%
df.dropna(axis = 1,inplace = True)

# %%
df.shape
# Out:
# (267419, 18)

# %%
df.head()
# Out:
#         Region  Residence Type  Family Composition  Population Base  Sex  Age  \
# 302321       0               1                   5                1    2    5
# 302322       0               1                   2                1    2    2
# 302323       0               1                   2                1    2    5
# 302324       0               1                   2                1    2    6
# 302325       0               1                   5                1    2    6
#
#         Marital Status  Student  Country of Birth  Health  Ethnic Group  \
# 302321               4        2                 1       3             1
# 302322               1        1                 1       1             1
# 302323               2        2                 1       3             1
# 302324               2        2                 1       1             1
# 302325               3        2                 1       2             1
#
#         Religion  Economic Activity  Occupation  Industry  \
# ...

# %%
df.isnull().sum()
# Out:
# Region                       0
# Residence Type               0
# Family Composition           0
# Population Base              0
# Sex                          0
# Age                          0
# Marital Status               0
# Student                      0
# Country of Birth             0
# Health                       0
# Ethnic Group                 0
# Religion                     0
# Economic Activity            0
# Occupation                   0
# Industry                     0
# Hours worked per week        0
# No of hours                  0
# Approximated Social Grade    0
# dtype: int64

# %%
df.dtypes
# Out:
# Region                         int64
# Residence Type                 int64
# Family Composition             int64
# Population Base                int64
# Sex                            int64
# Age                            int64
# Marital Status                 int64
# Student                        int64
# Country of Birth               int64
# Health                         int64
# Ethnic Group                   int64
# Religion                       int64
# Economic Activity              int64
# Occupation                     int64
# Industry                       int64
# Hours worked per week          int64
# No of hours                  float64
# Approximated Social Grade      int64
# dtype: object

# %%
X = df[['Region', 'Residence Type', 'Family Composition', 'Population Base',
       'Sex', 'Age', 'Marital Status', 'Student', 'Country of Birth', 'Health',
       'Ethnic Group', 'Religion', 'Economic Activity', 'Occupation',
       'Industry', 'Hours worked per week',
       'Approximated Social Grade']].values     # predictor attributes
y = df[['No of hours']].values                  # target attribute

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %% [markdown]
# #                Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# initialize the Naive Bayes classifier
LR = LinearRegression()

#fit the classifier to the data
LR.fit(X_train,y_train)

#use the resulting model to predict value on the test sey
y_pred = LR.predict(X_test)

#performance metrics
from sklearn import metrics
from sklearn.metrics import r2_score

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)), '\n')

print("R2 score:", r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.077503779885229
# Mean Squared Error: 22.5702731698088
# Root Mean Squared Error: 4.750818157939619
#
# R2 score: 0.8760767117270034

# %% [markdown]
# # CatBoost Regressor

# %%
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error, f1_score, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV

cb_model = CatBoostRegressor(loss_function='RMSE', logging_level='Silent')
cb_model.fit(X_train, y_train)
preds = cb_model.predict(X_test) 

print('MAE:', mean_absolute_error(y_test, preds))
print('MSE:', mean_squared_error(y_test, preds))
print('RMSE:', np.sqrt(mean_squared_error(y_test, preds)))
cb_r2_score=r2_score(y_test, preds)
print('r2_score',cb_r2_score)
# Out:
# MAE: 4.0759211534288236
# MSE: 22.57330324423852
# RMSE: 4.751137047511734
# r2_score 0.8760600749417852

# %% [markdown]
# ## Hyperparameter tuning

# %%
cb = CatBoostRegressor(loss_function='RMSE', logging_level='Silent')
cb_params = {"iterations": [300, 350],
                   "learning_rate": [0.1, 0.2],
                   "depth": [3, 5]}
cb_random = GridSearchCV(estimator=cb,param_grid=cb_params, n_jobs=-1)

cb_random.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=<catboost.core.CatBoostRegressor object at 0x31c07b9d0>,
#              n_jobs=-1,
#              param_grid={'depth': [3, 5], 'iterations': [300, 350],
#                          'learning_rate': [0.1, 0.2]})

# %%
print(cb_random.best_params_)

final_model = cb.set_params(**cb_random.best_params_, random_state=17).fit(X_train, y_train)
# Out:
# {'depth': 3, 'iterations': 300, 'learning_rate': 0.1}

# %%
cat_pred = final_model.predict(X_test)
print('MAE:', mean_absolute_error(y_test, cat_pred))
print('MSE:', mean_squared_error(y_test, cat_pred))
print('RMSE:', np.sqrt(mean_squared_error(y_test, cat_pred)))
print('r2_score:', r2_score(y_test, cat_pred))
# Out:
# MAE: 4.069803485773446
# MSE: 22.44825650596333
# RMSE: 4.737959107671079
# r2_score: 0.8767466507257062

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt

# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1.fit(X_train,y_train)
regr_2.fit(X_train,y_train)

# Predict
y1_pred = regr_1.predict(X_test)
y2_pred = regr_2.predict(X_test)

# %%
#performance metrics
from sklearn import metrics
from sklearn.metrics import r2_score

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y2_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y2_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y2_pred)), '\n')

print("R2 score:", r2_score(y_test, y1_pred))

# Evaluating the model using Adjusted R² Evaluation Metric
adj_r2 = 1 - (1-r2_score(y_test, y2_pred))*(len(y2_pred)-1)/(len(y2_pred)-X_test.shape[1]-1)
print("Adjusted R2 score:", adj_r2)
# Out:
# Mean Absolute Error: 4.0703703458697955
# Mean Squared Error: 22.45539860355624
# Root Mean Squared Error: 4.738712758076421
#
# R2 score: 0.8767726056467369
# Adjusted R2 score: 0.8766760771778794

# %% [markdown]
# # Rule Mining

# %%
df = pd.read_csv('Census.csv')
df.head()
# Out:
#    Person ID     Region Residence Type  Family Composition  Population Base  \
# 0    7394816  E12000001              H                   2                1
# 1    7394832  E12000001              H                   3                1
# 2    7394719  E12000001              H                   2                1
# 3    7394840  E12000001              H                   1                1
# 4    7394711  E12000001              H                   2                1
#
#    Sex  Age  Marital Status  Student  Country of Birth  Health  Ethnic Group  \
# 0    2    6               2        2                 1       2             1
# 1    2    1               1        2                 1       2             1
# 2    1    7               2        2                 1       1             1
# 3    2    6               4        2                 1       3             1
# 4    1    1               1        1                 1       1             1
#
# ...

# %%
from apyori import apriori

# %%
df['Family Composition'] = df['Family Composition'].astype('str')
df['Population Base'] = df['Population Base'].astype('str')
df['Sex'] = df['Sex'].astype('str')
df['Age'] = df['Age'].astype('str')
df['Marital Status'] = df['Marital Status'].astype('str')
df['Student'] = df['Student'].astype('str')
df['Country of Birth'] = df['Country of Birth'].astype('str')
df['Health'] = df['Health'].astype('str')
df['Ethnic Group'] = df['Ethnic Group'].astype('str')
df['Religion'] = df['Religion'].astype('str')
df['Economic Activity'] = df['Economic Activity'].astype('str')
df['Occupation'] = df['Occupation'].astype('str')
df['Industry'] = df['Industry'].astype('str')
df['Hours worked per week'] = df['Hours worked per week'].astype('str')
df['Approximated Social Grade'] = df['Approximated Social Grade'].astype('str')

# %%
df['Region'] = df['Region'].replace({
    'E12000008': 'South East',
    'E12000007': 'London',
    'E12000006': 'East of England',
    'E12000005': 'West Midlands',
    'E12000004': 'East Midlands',
    'E12000003': 'Yorkshire and the Humber',
    'E12000002': 'North West',
    'E12000001': 'North East',
    'E12000009': 'South West',
    'W92000004': 'Wales'
})

df['Residence Type'] = df['Residence Type'].replace({
    'C': 'communal establishment',
    'H':'Not a communal establishment'
})

df['Family Composition'] = df['Family Composition'].replace({
    '1': 'Not in a family',
    '2': 'Married',
    '3':'Cohabiting couple family',
    '4': 'Lone male parent family',
    '5':'Lone female parent family',
    '6':'Other related family',
    '-9':'short-term resident'
})

df['Population Base'] = df['Population Base'].replace({
    '1':'Usual resident',
    '2':'Student living away from home',
    '3':'Short term resident'
})

df['Sex'] = df['Sex'].replace({
    '1': 'Male',
    '2':'Female'
})

df['Age'] = df['Age'].replace({
    '1': '0 to 15',
    '2':'16 to 24',
    '3':'25 to 34',
    '4':'35 to 44',
    '5':'45 to 54',
    '6':'55 to 64',
    '7':'65 to 74',
    '8':'75 and over' 
})
df['Marital Status'] = df['Marital Status'].replace({
    '1': 'Single',
    '2': 'Married',
    '3': 'Separated but still legally married',
    '4': 'Divorced',
    '5':'Widowed'
})

df['Student'] = df['Student'].replace({
    '1': 'Yes',
    '2':'No'
})

df['Country of Birth'] = df['Country of Birth'].replace({
    '1': 'UK',
    '2':'Non UK',
    '-9':'Students or schoolchildren living away during term-time'
})

df['Health'] = df['Health'].replace({
    '1': 'Very good health',
    '2':'Good health',
    '3':'Fair health',
    '4':'Bad health',
    '5':'Very bad health',
   '-9':'Students or schoolchildren living away during term-time'
})

df['Ethnic Group'] = df['Ethnic Group'].replace({
    '1':'White',
'2':'Mixed',
'3': 'Asian and Asian British',
'4':'Black or Black British',
'5':'Chinese',
'-9': 'students or schoolchildren living away during term-time'
})

df['Religion'] = df['Religion'].replace({
    '1': 'No religion',
'2':'Christian',
'3': 'Buddhist',
'4':'Hindu',
'5': 'Jewish',
'6':'Muslim',
'7': 'Sikh',
'8':'Other religion',
'9':'Not stated',
'-9':'students or schoolchildren living away during term-time'
})

df['Economic Activity'] = df['Economic Activity'].replace({
    '1': 'Employee',
    '2': 'Self-employed',
    '3': 'Unemployed',
    '4': 'Full-time student',
    '5': 'Retired',
    '6': 'Student',
    '7': 'Looking after home or family',
    '8': 'Long-term sick or disabled',
    '9': 'Other',
    '-9': 'students or schoolchildren living away during term-time'
})

df['Occupation'] = df['Occupation'].replace({
    '1': 'Managers',
    '2': 'Professional Occupations',
    '3': 'Associate Technical Occupations',
    '4': 'Administrative and Secretarial Occupations',
    '5': 'Skilled Trades Occupations',
    '6': 'Caring Other Service Occupations',
    '7': 'Sales and Customer Service Occupations',
    '8': 'Process, Plant and Machine Operatives',
    '9': 'Elementary Occupations',
    '-9': 'People aged under 16'
})

df['Industry'] = df['Industry'].replace({
    '1': 'Agriculture and fishing',
    '2': 'Mining and Manufacturing',
    '3': 'Construction',
    '4': 'Wholesale and retail trade',
    '5': 'Accommodation and food service',
    '6': 'Transport and storage',
    '7': 'Financial and insurance',
    '8': 'Real estate activities',
    '9': 'Public administration and defence',
    '10': 'Education',
    '11': 'Human health and social work',
    '12': 'Other community activities',
    '-9': 'People aged under 16'
})

df['Hours worked per week'] = df['Hours worked per week'].replace({
   '1' :'15 or less',
    '2': '16 to 30',
    '3':'31 to 48',
    '4': '49 or more',
    '-9':'people not working'
})

df['Approximated Social Grade'] = df['Approximated Social Grade'].replace({
    '1': 'AB',
    '2':'C1',
   '3': 'C2',
   '4':'DE',
   '-9': 'People aged under 16'
})

# %%
df['No of hours'].fillna(df['No of hours'].median(),inplace = True)

# %%
df.dropna(axis = 0,inplace = True)

# %%
df.dropna(axis = 1,inplace = True)

# %%
df.shape
# Out:
# (569740, 19)

# %%
df.drop('Person ID',axis = 1,inplace = True)

# %%
df1 = df.sample(frac=0.05, replace=False, random_state=1)
df1.shape
# Out:
# (28487, 18)

# %%
df.head()
# Out:
#        Region                Residence Type        Family Composition  \
# 0  North East  Not a communal establishment                   Married
# 1  North East  Not a communal establishment  Cohabiting couple family
# 2  North East  Not a communal establishment                   Married
# 3  North East  Not a communal establishment           Not in a family
# 4  North East  Not a communal establishment                   Married
#
#   Population Base     Sex       Age Marital Status Student Country of Birth  \
# 0  Usual resident  Female  55 to 64        Married      No               UK
# 1  Usual resident  Female   0 to 15         Single      No               UK
# 2  Usual resident    Male  65 to 74        Married      No               UK
# 3  Usual resident  Female  55 to 64       Divorced      No               UK
# 4  Usual resident    Male   0 to 15         Single     Yes               UK
#
#              Health Ethnic Group     Religion  \
# ...

# %%
data_list = []
for row in range(0, 3256):
    data_list.append([str(df1.values[row,column]) for column in range(0, 18)])
    
rules = apriori(data_list, min_support=0.25, min_confidence=0.25, min_length=2)
results = list(rules)

# %%
print(results)
# Out:
# [RelationRecord(items=frozenset({'31 to 48'}), support=0.2788697788697789, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'31 to 48'}), confidence=0.2788697788697789, lift=1.0)]), RelationRecord(items=frozenset({'37.0'}), support=0.5426904176904177, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'37.0'}), confidence=0.5426904176904177, lift=1.0)]), RelationRecord(items=frozenset({'C1'}), support=0.27671990171990174, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'C1'}), confidence=0.27671990171990174, lift=1.0)]), RelationRecord(items=frozenset({'Christian'}), support=0.577088452088452, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Christian'}), confidence=0.577088452088452, lift=1.0)]), RelationRecord(items=frozenset({'Employee'}), support=0.38052825552825553, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'E
# ...

# %%
#Put the results into a dataframe to have the rules listed in a table
df2 = pd.DataFrame(columns=('Items','Antecedent','Consequent','Support','Confidence','Lift'))

Support =[]
Confidence = []
Lift = []
Items = []
Antecedent = []
Consequent=[]

for RelationRecord in results:
    for ordered_stat in RelationRecord.ordered_statistics:
        Support.append(RelationRecord.support)
        Items.append(RelationRecord.items)
        Antecedent.append(ordered_stat.items_base)
        Consequent.append(ordered_stat.items_add)
        Confidence.append(ordered_stat.confidence)
        Lift.append(ordered_stat.lift)

df2['Items'] = list(map(set, Items))                                   
df2['Antecedent'] = list(map(set, Antecedent))
df2['Consequent'] = list(map(set, Consequent))
df2['Support'] = Support
df2['Confidence'] = Confidence
df2['Lift']= Lift

#Sort resulted dataframe by Lift
df2.sort_values(by ='Lift', ascending = False, inplace = True)

# %%
 df2.reset_index(drop=True, inplace=True)

# %%
df2.shape
# Out:
# (8481, 6)

# %%
# Adjust pandas display options
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns

# %%
df2.loc[22]
# Out:
# Items         {UK, Not a communal establishment, No, Usual r...
# Antecedent    {UK, Not a communal establishment, No, Usual r...
# Consequent                                        {White, 37.0}
# Support                                                0.262899
# Confidence                                             0.951111
# Lift                                                   2.122562
# Name: 22, dtype: object

# %%
df2.head(100)
# Out:
#                                                 Items  \
# 0   {UK, Not a communal establishment, 37.0, Usual...
# 1   {UK, Not a communal establishment, 37.0, Usual...
# 2   {UK, Not a communal establishment, 37.0, Usual...
# 3   {UK, Not a communal establishment, 37.0, Usual...
# 4   {UK, Not a communal establishment, 37.0, peopl...
# 5   {UK, Not a communal establishment, 37.0, peopl...
# 6   {UK, No, Usual resident, people not working, W...
# 7   {UK, No, Usual resident, people not working, W...
# 8   {UK, Not a communal establishment, No, Usual r...
# 9   {UK, Not a communal establishment, No, Usual r...
# 10          {UK, No, people not working, White, 37.0}
# 11  {UK, No, Usual resident, people not working, W...
# 12          {UK, No, people not working, White, 37.0}
# 13  {UK, No, Usual resident, people not working, W...
# 14  {UK, Not a communal establishment, No, Usual r...
# 15  {UK, Not a communal establishment, No, people ...
# ...

# %%
df2['Antecedent']
# Out:
# 0       {Not a communal establishment, people not work...
# 1                                   {Christian, 37.0, UK}
# 2                   {Christian, Usual resident, 37.0, UK}
# 3       {Not a communal establishment, White, people n...
# 4                                   {Christian, 37.0, UK}
# 5       {Not a communal establishment, White, people n...
# 6                            {UK, No, people not working}
# 7                           {White, 37.0, Usual resident}
# 8                            {UK, No, people not working}
# 9       {Not a communal establishment, White, 37.0, Us...
# 10                                          {White, 37.0}
# 11                                          {White, 37.0}
# 12                           {UK, No, people not working}
# 13           {UK, No, Usual resident, people not working}
# 14           {UK, No, Usual resident, people not working}
# 15                           {UK, No, people not working}
# ...

# %%
df2['Consequent']
# Out:
# 0                                   {UK, 37.0, Christian}
# 1       {Not a communal establishment, people not work...
# 2       {Not a communal establishment, White, people n...
# 3                   {UK, 37.0, Christian, Usual resident}
# 4       {Not a communal establishment, White, people n...
# 5                                   {UK, 37.0, Christian}
# 6                           {37.0, White, Usual resident}
# 7                            {UK, No, people not working}
# 8       {Not a communal establishment, 37.0, White, Us...
# 9                            {UK, No, people not working}
# 10                           {UK, No, people not working}
# 11           {UK, No, Usual resident, people not working}
# 12                                          {White, 37.0}
# 13                                          {White, 37.0}
# 14            {Not a communal establishment, White, 37.0}
# 15            {Not a communal establishment, White, 37.0}
# ...

# %%
df2.iloc[99,[1,2]]
# Out:
# Antecedent    {Not a communal establishment, White, people n...
# Consequent                                    {37.0, Christian}
# Name: 99, dtype: object

# %% [markdown]
# # FpGrowth

# %%
from mlxtend.frequent_patterns import fpgrowth, association_rules
import pandas as pd
# Convert to one-hot encoded dataframe
itemset = pd.DataFrame([
    {item: item in transaction for item in set(sum(data_list, []))}
    for transaction in data_list
])



#  Generate frequent itemsets using FP-Growth
frequent_itemsets = fpgrowth(itemset, min_support=0.4, use_colnames=True)
print("\nFrequent Itemsets:\n", frequent_itemsets)
# Out:
# Frequent Itemsets:
#        support                                           itemsets
# 0    0.986486                                   (Usual resident)
# 1    0.980344                     (Not a communal establishment)
# 2    0.779484                                               (No)
# 3    0.577088                                        (Christian)
# 4    0.545455                                          (Married)
# 5    0.542690                                             (37.0)
# 6    0.530098                               (people not working)
# 7    0.499386                                           (Female)
# 8    0.462838                                 (Very good health)
# 9    0.850123                                            (White)
# 10   0.500614                                             (Male)
# 11   0.468980                                           (Single)
# 12   0.857801                                               (UK)
# ...

# %%
#  Generate association rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7,num_itemsets=10)
print("\nAssociation Rules:\n", rules)
# Out:
# Association Rules:
#                                             antecedents  \
# 0                       (Not a communal establishment)
# 1                                     (Usual resident)
# 2                                                 (No)
# 3                                     (Usual resident)
# 4                       (Not a communal establishment)
# 5                                                 (No)
# 6                                                 (No)
# 7                                              (White)
# 8                                                 (UK)
# 9                                                 (No)
# 10                  (Not a communal establishment, No)
# 11      (Not a communal establishment, Usual resident)
# 12                                (No, Usual resident)
# 13                      (Not a communal establishment)
# 14                                                (No)
# 15                                    (Usual resident)
# ...

# %%
from mlxtend.frequent_patterns import association_rules

rules_df = association_rules(
    frequent_itemsets,
    metric="confidence",
    min_threshold=0.02,num_itemsets=10
)

# Set the column names to be used
columns = [
    "antecedents",
    "consequents",
    "support",
    "confidence",
    "lift",
]

# Sort by support, confidence, and lift in descending order and display up to 4 decimal places
data = rules_df.sort_values(by=["support", "confidence", "lift"], ascending=False)[columns].reset_index(drop=True).round(
    4
)

# %%
data.head(100)
# Out:
#                                           antecedents  \
# 0                      (Not a communal establishment)
# 1                                    (Usual resident)
# 2                                                (UK)
# 3                                    (Usual resident)
# 4                                             (White)
# 5                                    (Usual resident)
# 6                  (UK, Not a communal establishment)
# 7                                                (UK)
# 8                                                (UK)
# 9                                (UK, Usual resident)
# 10     (Not a communal establishment, Usual resident)
# 11                     (Not a communal establishment)
# 12                     (Not a communal establishment)
# 13                                   (Usual resident)
# 14                                            (White)
# 15                     (Not a communal establishment)
# ...

# %% [markdown]
# # Clustering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
df = pd.read_csv('Census.csv')
df.head()
# Out:
#    Person ID     Region Residence Type  Family Composition  Population Base  \
# 0    7394816  E12000001              H                   2                1
# 1    7394832  E12000001              H                   3                1
# 2    7394719  E12000001              H                   2                1
# 3    7394840  E12000001              H                   1                1
# 4    7394711  E12000001              H                   2                1
#
#    Sex  Age  Marital Status  Student  Country of Birth  Health  Ethnic Group  \
# 0    2    6               2        2                 1       2             1
# 1    2    1               1        2                 1       2             1
# 2    1    7               2        2                 1       1             1
# 3    2    6               4        2                 1       3             1
# 4    1    1               1        1                 1       1             1
#
# ...

# %%
df.isnull().sum()
# Out:
# Person ID                         0
# Region                            0
# Residence Type                    0
# Family Composition                0
# Population Base                   0
# Sex                               0
# Age                               0
# Marital Status                    0
# Student                           0
# Country of Birth                  0
# Health                            0
# Ethnic Group                      0
# Religion                          0
# Economic Activity                 0
# Occupation                        0
# Industry                          0
# Hours worked per week             0
# No of hours                  302321
# Approximated Social Grade         0
# dtype: int64

# %%
df['No of hours'].fillna(df['No of hours'].median(),inplace = True)

# %%
df.replace(-9,0,inplace = True)

# %%
df.drop('Person ID',axis = 1,inplace = True)

# %%
df.shape
# Out:
# (569740, 18)

# %%
df.head()
# Out:
#       Region Residence Type  Family Composition  Population Base  Sex  Age  \
# 0  E12000001              H                   2                1    2    6
# 1  E12000001              H                   3                1    2    1
# 2  E12000001              H                   2                1    1    7
# 3  E12000001              H                   1                1    2    6
# 4  E12000001              H                   2                1    1    1
#
#    Marital Status  Student  Country of Birth  Health  Ethnic Group  Religion  \
# 0               2        2                 1       2             1         2
# 1               1        2                 1       2             1         1
# 2               2        2                 1       1             1         2
# 3               4        2                 1       3             1         2
# 4               1        1                 1       1             1         1
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
df['Residence Type'] = LE.fit_transform(df['Residence Type'])
df['Region'] = LE.fit_transform(df['Region'])

# %%
df1 = df.sample(frac=0.05, replace=False, random_state=1)
df1.shape
# Out:
# (28487, 18)

# %%
#standardise the data 
scaler = StandardScaler()
scaled_features = scaler.fit_transform(df1.values)
scaled_features_df = pd.DataFrame(scaled_features, index=df1.index, columns=df1.columns)
scaled_features_df.describe()
# Out:
#              Region  Residence Type  Family Composition  Population Base  \
# count  2.848700e+04    2.848700e+04        2.848700e+04     2.848700e+04
# mean  -1.147988e-16    1.419240e-16        7.233383e-17     3.339828e-16
# std    1.000018e+00    1.000018e+00        1.000018e+00     1.000018e+00
# min   -1.790774e+00   -7.413946e+00       -1.834338e+00    -1.166442e-01
# 25%   -1.026030e+00    1.348809e-01       -2.494187e-01    -1.166442e-01
# 50%    1.210861e-01    1.348809e-01       -2.494187e-01    -1.166442e-01
# 75%    8.858302e-01    1.348809e-01        5.430407e-01    -1.166442e-01
# max    1.650574e+00    1.348809e-01        2.920419e+00     1.273768e+01
#
#                 Sex           Age  Marital Status       Student  \
# count  2.848700e+04  2.848700e+04    2.848700e+04  2.848700e+04
# mean   1.514022e-16  1.721046e-17   -1.089996e-16  1.945531e-16
# std    1.000018e+00  1.000018e+00    1.000018e+00  1.000018e+00
# ...

# %% [markdown]
# ## k - means

# %%
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(scaled_features_df)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[-0.01577389, -0.06855865, -0.22491273, -0.10387289,  0.20851689,
#          0.98298745,  0.68121676,  0.48734532,  0.04866036,  0.82507309,
#         -0.07737023,  0.05078918,  1.26795334,  0.37904146,  0.18321699,
#         -0.84770209,  0.02126353,  0.54318612],
#        [-0.01418912, -0.11844971,  0.23229203,  0.3120146 , -0.06115478,
#         -1.21875109, -0.75741249, -1.43440685, -0.21459067, -0.60040865,
#          0.15221679,  0.01130049, -0.52785698, -1.00468959, -1.09689442,
#         -0.84890215, -0.00211494, -1.14544295],
#        [ 0.01706068,  0.10433033,  0.01225978, -0.10315694, -0.09332746,
#          0.054588  , -0.00851293,  0.46831363,  0.08469338, -0.17877467,
#         -0.03421543, -0.03665574, -0.48459856,  0.30526993,  0.47245088,
#          0.96276034, -0.01170762,  0.28102726]])

# %%
# Compute the silhouette score 
kmeans_silhouette = silhouette_score(scaled_features_df, kmeans.labels_).round(2)
kmeans_silhouette
# Out:
# 0.18

# %%
from yellowbrick.cluster import KElbowVisualizer

# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(2,10), metric='calinski_harabasz')

visualizer.fit(scaled_features_df)        # Fit the data to the visualizer
visualizer.show()                            # Finalize and render the figure
# Out:
# /Users/kiranpaudel/anaconda3/lib/python3.11/site-packages/yellowbrick/style/colors.py:35: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   mpl_ge_150 = LooseVersion(mpl.__version__) >= "1.5.0"
# /Users/kiranpaudel/anaconda3/lib/python3.11/site-packages/setuptools/_distutils/version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /Users/kiranpaudel/anaconda3/lib/python3.11/site-packages/yellowbrick/style/rcmod.py:31: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   mpl_ge_150 = LooseVersion(mpl.__version__) >= "1.5.0"
# /Users/kiranpaudel/anaconda3/lib/python3.11/site-packages/setuptools/_distutils/version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# ...

# %%
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(scaled_features_df)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
scaled_features_df.shape
# Out:
# (28487, 18)

# %%
scaled_features_df.head()
# Out:
#           Region  Residence Type  Family Composition  Population Base  \
# 257725  0.503458        0.134881           -0.249419        -0.116644
# 298417 -0.261286       -7.413946           -1.834338        12.737682
# 440058  0.885830        0.134881           -0.249419        -0.116644
# 352710 -0.643658        0.134881           -0.249419        -0.116644
# 150562 -0.261286        0.134881           -0.249419        -0.116644
#
#              Sex       Age  Marital Status   Student  Country of Birth  \
# 257725  0.998632  0.005318        0.136121  0.529393          2.438399
# 298417 -1.001370 -1.347370       -0.762736 -1.888955          2.438399
# 440058 -1.001370 -0.445578        0.136121  0.529393          2.438399
# 352710  0.998632 -0.445578        0.136121  0.529393         -0.335448
# 150562 -1.001370  0.907110        0.136121  0.529393         -0.335448
#
#           Health  Ethnic Group  Religion  Economic Activity  Occupation  \
# ...

# %%
kmeans.labels_
# Out:
# array([0, 1, 0, ..., 1, 0, 0], dtype=int32)

# %%
#append dataframe with cluster number
scaled_features_df['cluster'] = kmeans.labels_

# %%
kmeans.labels_ == 0
# Out:
# array([ True, False,  True, ..., False,  True,  True])

# %%
#view proterties of each cluster
cluster1=scaled_features_df.query("cluster == 0")
cluster2=scaled_features_df.query("cluster == 1")

# %%
cluster1.head()
# Out:
#           Region  Residence Type  Family Composition  Population Base  \
# 257725  0.503458        0.134881           -0.249419        -0.116644
# 440058  0.885830        0.134881           -0.249419        -0.116644
# 352710 -0.643658        0.134881           -0.249419        -0.116644
# 150562 -0.261286        0.134881           -0.249419        -0.116644
# 543642  1.268202        0.134881           -0.249419        -0.116644
#
#              Sex       Age  Marital Status   Student  Country of Birth  \
# 257725  0.998632  0.005318        0.136121  0.529393          2.438399
# 440058 -1.001370 -0.445578        0.136121  0.529393          2.438399
# 352710  0.998632 -0.445578        0.136121  0.529393         -0.335448
# 150562 -1.001370  0.907110        0.136121  0.529393         -0.335448
# 543642 -1.001370 -0.445578        0.136121  0.529393         -0.335448
#
#           Health  Ethnic Group  Religion  Economic Activity  Occupation  \
# ...

# %%
cluster1.shape
# Out:
# (21487, 19)

# %%
cluster1.describe()
# Out:
#              Region  Residence Type  Family Composition  Population Base  \
# count  21487.000000    21487.000000        21487.000000     21487.000000
# mean       0.004668        0.044943           -0.075378        -0.107072
# std        1.004500        0.819066            0.918252         0.350647
# min       -1.790774       -7.413946           -1.834338        -0.116644
# 25%       -1.026030        0.134881           -0.249419        -0.116644
# 50%        0.121086        0.134881           -0.249419        -0.116644
# 75%        0.885830        0.134881           -0.249419        -0.116644
# max        1.650574        0.134881            2.920419        12.737682
#
#                 Sex           Age  Marital Status       Student  \
# count  21487.000000  21487.000000    21487.000000  21487.000000
# mean       0.022320      0.397940        0.246391      0.465240
# std        0.999744      0.813636        1.037124      0.388634
# ...

# %%
cluster2.head()
# Out:
#           Region  Residence Type  Family Composition  Population Base  \
# 298417 -0.261286       -7.413946           -1.834338        12.737682
# 296165  1.650574       -7.413946           -1.834338        -0.116644
# 9483   -1.026030        0.134881           -0.249419        -0.116644
# 296502  0.121086       -7.413946           -1.834338        -0.116644
# 81915   0.885830        0.134881           -0.249419        -0.116644
#
#              Sex       Age  Marital Status   Student  Country of Birth  \
# 298417 -1.001370 -1.347370       -0.762736 -1.888955          2.438399
# 296165 -1.001370 -0.896474       -0.762736 -1.888955         -0.335448
# 9483    0.998632 -1.347370       -0.762736 -1.888955         -0.335448
# 296502 -1.001370 -0.445578       -0.762736  0.529393         -0.335448
# 81915  -1.001370 -1.347370       -0.762736  0.529393         -0.335448
#
#           Health  Ethnic Group  Religion  Economic Activity  Occupation  \
# ...

# %%
cluster2.shape
# Out:
# (7000, 19)

# %%
cluster2.describe()
# Out:
#             Region  Residence Type  Family Composition  Population Base  \
# count  7000.000000     7000.000000         7000.000000      7000.000000
# mean     -0.014328       -0.137955            0.231378         0.328666
# std       0.986064        1.409055            1.187728         1.884004
# min      -1.790774       -7.413946           -1.834338        -0.116644
# 25%      -1.026030        0.134881           -0.249419        -0.116644
# 50%       0.121086        0.134881           -0.249419        -0.116644
# 75%       0.885830        0.134881            0.543041        -0.116644
# max       1.650574        0.134881            2.920419        12.737682
#
#                Sex          Age  Marital Status      Student  \
# count  7000.000000  7000.000000     7000.000000  7000.000000
# mean     -0.068512    -1.221505       -0.756315    -1.428087
# std       0.997816     0.243820        0.098262     0.949879
# min      -1.001370    -1.347370       -0.762736    -1.888955
# ...

# %%
kmeans.cluster_centers_
# Out:
# array([[ 0.00451072,  0.04491772, -0.07558749, -0.10706973,  0.02241944,
#          0.39828055,  0.24667303,  0.46578495,  0.07066678,  0.19553332,
#         -0.05053782, -0.00426876,  0.17731706,  0.33756916,  0.36344651,
#          0.27595511, -0.00400395,  0.38093883],
#        [-0.01383027, -0.1377216 ,  0.23175777,  0.32828502, -0.06873993,
#         -1.2211625 , -0.75632076, -1.42813681, -0.21667045, -0.599522  ,
#          0.15495333,  0.01308839, -0.54366938, -1.03501616, -1.11435834,
#         -0.84610215,  0.01227646, -1.16799131]])

# %%
cluster1_mean = kmeans.cluster_centers_[0]
cluster2_mean = kmeans.cluster_centers_[1]

# %%
cluster1.keys()
# Out:
# Index(['Region', 'Residence Type', 'Family Composition', 'Population Base',
#        'Sex', 'Age', 'Marital Status', 'Student', 'Country of Birth', 'Health',
#        'Ethnic Group', 'Religion', 'Economic Activity', 'Occupation',
#        'Industry', 'Hours worked per week', 'No of hours',
#        'Approximated Social Grade', 'cluster'],
#       dtype='object')

# %%
len(cluster1.keys())
# Out:
# 19

# %%
cluster1_mean
# Out:
# array([ 0.00451072,  0.04491772, -0.07558749, -0.10706973,  0.02241944,
#         0.39828055,  0.24667303,  0.46578495,  0.07066678,  0.19553332,
#        -0.05053782, -0.00426876,  0.17731706,  0.33756916,  0.36344651,
#         0.27595511, -0.00400395,  0.38093883])

# %%
cluster2_mean
# Out:
# array([-0.01383027, -0.1377216 ,  0.23175777,  0.32828502, -0.06873993,
#        -1.2211625 , -0.75632076, -1.42813681, -0.21667045, -0.599522  ,
#         0.15495333,  0.01308839, -0.54366938, -1.03501616, -1.11435834,
#        -0.84610215,  0.01227646, -1.16799131])

# %%
cluster1_mean_p1 = cluster1_mean[:8]

# %%
cluster1_mean_p1
# Out:
# array([ 0.00451072,  0.04491772, -0.07558749, -0.10706973,  0.02241944,
#         0.39828055,  0.24667303,  0.46578495])

# %%
cluster2_mean_p1 = cluster2_mean[:8]
cluster2_mean_p1
# Out:
# array([-0.01383027, -0.1377216 ,  0.23175777,  0.32828502, -0.06873993,
#        -1.2211625 , -0.75632076, -1.42813681])

# %%
X = cluster1.keys()[:8]

  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, cluster1_mean_p1, 0.4, label = 'Cluster1')
plt.bar(X_axis + 0.2, cluster2_mean_p1, 0.4, label = 'Cluster2')
  
plt.xticks(X_axis, X, rotation='vertical')
plt.xlabel("Groups")
#plt.subplots_adjust(bottom=0.1)
plt.ylabel("Mean values")
plt.title("Mean values per attribute")
plt.legend()
plt.show()

# %%
cluster1_mean_p2 = cluster1_mean[9:]
cluster2_mean_p2 = cluster2_mean[9:]

# %%
cluster1_mean_p2
# Out:
# array([ 0.19553332, -0.05053782, -0.00426876,  0.17731706,  0.33756916,
#         0.36344651,  0.27595511, -0.00400395,  0.38093883])

# %%
cluster1.keys()[9:-2]
# Out:
# Index(['Health', 'Ethnic Group', 'Religion', 'Economic Activity', 'Occupation',
#        'Industry', 'Hours worked per week', 'No of hours'],
#       dtype='object')

# %%
X = cluster1.keys()[9:-1]

  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, cluster1_mean_p2, 0.4, label = 'Cluster1')
plt.bar(X_axis + 0.2, cluster2_mean_p2, 0.4, label = 'Cluster2')
  
plt.xticks(X_axis, X, rotation='vertical')
plt.xlabel("Groups")
plt.subplots_adjust(bottom=0.15, wspace=0.05)
plt.ylabel("Mean values")
plt.title("Mean values per attribute")
plt.legend()
plt.show()

# %% [markdown]
# ##             Hierarchical Clustering

# %%
from sklearn.cluster import AgglomerativeClustering

X = scaled_features_df.sample(frac=0.1, replace=False, random_state=1)

# setting distance_threshold=0 ensures we compute the full tree.
cluster = AgglomerativeClustering(distance_threshold=0, n_clusters=None)

#change the parameters
#cluster = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward')
cluster.fit(X)
# Out:
# AgglomerativeClustering(distance_threshold=0, n_clusters=None)

# %%
from scipy.cluster.hierarchy import dendrogram

def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack(
        [model.children_, model.distances_, counts]
    ).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

plt.title("Hierarchical Clustering Dendrogram")
plot_dendrogram(cluster)
# plot the top three levels of the dendrogram
#plot_dendrogram(model, truncate_mode="level", p=3)
plt.xlabel("Number of points in node (or index of point if no parenthesis).")
plt.show()

# %%
cluster.labels_
# Out:
# array([2158, 2571, 2595, ...,    1,    2,    0])

# %%
#change the parameters
cluster = AgglomerativeClustering(n_clusters=2, linkage='ward')
cluster.fit_predict(X)
# Out:
# array([1, 1, 1, ..., 1, 1, 0])

# %%
#append dataframe with cluster number
X['cluster_no'] = cluster.labels_

# %%
X.head()
# Out:
#           Region  Residence Type  Family Composition  Population Base  \
# 468895  0.885830        0.134881           -1.041878        -0.116644
# 139292 -0.643658        0.134881           -0.249419        -0.116644
# 340095  0.121086        0.134881           -0.249419        -0.116644
# 135771 -0.643658        0.134881           -0.249419        -0.116644
# 153037  0.121086        0.134881           -0.249419        -0.116644
#
#              Sex       Age  Marital Status   Student  Country of Birth  \
# 468895 -1.001370  0.456214       -0.762736  0.529393         -0.335448
# 139292  0.998632  1.358006        0.136121  0.529393         -0.335448
# 340095  0.998632  1.358006        0.136121  0.529393         -0.335448
# 135771  0.998632 -0.445578        0.136121  0.529393         -0.335448
# 153037 -1.001370 -1.347370       -0.762736 -1.888955         -0.335448
#
#           Health  Ethnic Group  Religion  Economic Activity  Occupation  \
# ...

# %%
X.describe()
# Out:
#             Region  Residence Type  Family Composition  Population Base  \
# count  2849.000000     2849.000000         2849.000000      2849.000000
# mean     -0.004671       -0.000251            0.009820         0.025480
# std       1.012545        1.001088            1.026766         1.074545
# min      -1.790774       -7.413946           -1.834338        -0.116644
# 25%      -1.026030        0.134881           -0.249419        -0.116644
# 50%       0.121086        0.134881           -0.249419        -0.116644
# 75%       0.885830        0.134881            0.543041        -0.116644
# max       1.650574        0.134881            2.920419        12.737682
#
#                Sex          Age  Marital Status      Student  \
# count  2849.000000  2849.000000     2849.000000  2849.000000
# mean     -0.017164     0.006110        0.000456    -0.011319
# std       1.000052     1.006285        1.004542     1.007778
# min      -1.001370    -1.347370       -0.762736    -1.888955
# ...

# %%
#save each cluster data separately
cluster1=X.query("cluster_no == 0")
cluster2=X.query("cluster_no == 1")

# %%
cluster1.describe()
# Out:
#            Region  Residence Type  Family Composition  Population Base  \
# count  635.000000      635.000000          635.000000       635.000000
# mean    -0.009583        0.111105            0.228553         0.521011
# std      0.993588        0.423316            1.167456         2.206882
# min     -1.790774       -7.413946           -1.834338        -0.116644
# 25%     -1.026030        0.134881           -0.249419        -0.116644
# 50%      0.121086        0.134881           -0.249419        -0.116644
# 75%      0.885830        0.134881            0.543041        -0.116644
# max      1.650574        0.134881            2.920419        12.737682
#
#               Sex         Age  Marital Status     Student  Country of Birth  \
# count  635.000000  635.000000      635.000000  635.000000        635.000000
# mean    -0.037590   -1.236598       -0.757074   -1.424328         -0.488337
# std      1.000133    0.226283        0.071171    0.953512          0.802538
# ...

# %%
cluster2.describe()
# Out:
#             Region  Residence Type  Family Composition  Population Base  \
# count  2214.000000     2214.000000         2214.000000     2.214000e+03
# mean     -0.003263       -0.032189           -0.052915    -1.166442e-01
# std       1.018134        1.110777            0.973971     5.829988e-16
# min      -1.790774       -7.413946           -1.834338    -1.166442e-01
# 25%      -1.026030        0.134881           -0.249419    -1.166442e-01
# 50%       0.121086        0.134881           -0.249419    -1.166442e-01
# 75%       0.885830        0.134881           -0.249419    -1.166442e-01
# max       1.650574        0.134881            2.920419    -1.166442e-01
#
#                Sex          Age  Marital Status      Student  \
# count  2214.000000  2214.000000     2214.000000  2214.000000
# mean     -0.011306     0.362532        0.217724     0.393948
# std       1.000177     0.847511        1.041787     0.556190
# min      -1.001370    -1.347370       -0.762736    -1.888955
# ...

# %%
cluster1_mean = np.array(cluster1.mean())
cluster2_mean = np.array(cluster2.mean())

# %%
cluster1_mean
# Out:
# array([-0.00958283,  0.1111051 ,  0.22855288,  0.52101136, -0.03758955,
#        -1.23659831, -0.75707358, -1.42432785, -0.48833693, -0.61139753,
#        -0.01138993, -0.09628147, -0.64121124, -1.06893644, -1.10934735,
#        -0.84602237,  0.08442819, -1.20368611,  0.97165354,  0.        ])

# %%
cluster1_mean_p1 = cluster1_mean[:9]
cluster2_mean_p1 = cluster2_mean[:9]

# %%
X = cluster1.keys()[:9]
  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, cluster1_mean_p1, 0.3, label = 'Cluster1')
plt.bar(X_axis + 0.1, cluster2_mean_p1, 0.3, label = 'Cluster2')
  
plt.xticks(X_axis, X, rotation='vertical')
plt.xlabel("Groups")
#plt.subplots_adjust(bottom=0.1)
plt.ylabel("Mean values")
plt.title("Mean values per attribute")
plt.legend()
plt.show()

# %%
cluster1.keys()
# Out:
# Index(['Region', 'Residence Type', 'Family Composition', 'Population Base',
#        'Sex', 'Age', 'Marital Status', 'Student', 'Country of Birth', 'Health',
#        'Ethnic Group', 'Religion', 'Economic Activity', 'Occupation',
#        'Industry', 'Hours worked per week', 'No of hours',
#        'Approximated Social Grade', 'cluster', 'cluster_no'],
#       dtype='object')

# %%
cluster1_mean_p2 = cluster1_mean[8:-2]
cluster2_mean_p2 = cluster2_mean[8:-2]

X = cluster1.keys()[8:-2]
  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, cluster1_mean_p2, 0.3, label = 'Cluster1')
plt.bar(X_axis + 0.1, cluster2_mean_p2, 0.3, label = 'Cluster2')
  
plt.xticks(X_axis, X, rotation='vertical')
plt.xlabel("Groups")
plt.ylabel("Mean values")
plt.title("Mean values per attribute")
plt.legend()
plt.show()

# %%
from sklearn.mixture import GaussianMixture  # For Gaussian Mixture Model clustering
from sklearn.decomposition import PCA        # For dimensionality reduction
from sklearn.preprocessing import StandardScaler  # For scaling features
import matplotlib.pyplot as plt              # For visualization

#Sample a subset of the data (10% of the dataset)
X = scaled_features_df.sample(frac=0.1, replace=False, random_state=42)

#Scale the features for better performance of GMM
scaler = StandardScaler() 
X_scaled = scaler.fit_transform(X)  # Normalize the features to have zero mean and unit variance

#Create and fit a Gaussian Mixture Model
gmm = GaussianMixture(n_components=2, covariance_type='full', random_state=42) 

gmm.fit(X_scaled)

#Predict cluster labels for the dataset
labels = gmm.predict(X_scaled)  

#Reduce the dataset to 2 dimensions using PCA for visualization
pca = PCA(n_components=2)  # Reduce to 2 principal components
X_pca = pca.fit_transform(X_scaled)  # Apply PCA on scaled data

#Plot the clusters in a 2D space
plt.figure(figsize=(8, 6))  
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='viridis', s=50, alpha=0.7) 

plt.title("Clustering with Gaussian Mixture Model", fontsize=14) 
plt.xlabel("Principal Component 1 (PCA 1)", fontsize=12) 
plt.ylabel("Principal Component 2 (PCA 2)", fontsize=12) 
plt.colorbar(label="Cluster Label")  # Addding a color bar to indicate cluster labels
plt.grid(True) 
plt.show()
